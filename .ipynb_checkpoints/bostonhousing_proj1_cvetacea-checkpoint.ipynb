# %% [markdown]
# # Введение в машинное обучение
#
# ## Boston Housing

# %% [markdown]
# 1. Скачать Boston housing dataset по ссылке (https://github.com/mcsml/ml_basics/blob/master/train.csv) и разместить в той же директории, что и ваш Notebook. Описание данных можно найти здесь: https://www.kaggle.com/c/boston-housing.
# 2. Загрузить данные в DataFrame.
# 3. Построить график зависимости значений medv от значений dis.
# 4. Создать отдельный DataFrame, содержащий только данные для домов, чья цена выше средней цены всех домов в исходных данных.
# 5. Сохранить новый DataFrame в файл rich_boston.csv

# %% [markdown]
# Вызываем библиотеки, импортируем данные

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
bh_data = pd.read_csv('https://raw.githubusercontent.com/mcsml/ml_basics/master/train.csv')

# %%
bh_data.head(10)
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# 5  11  0.22489  12.5   7.87     0  0.524  6.377  94.3  6.3467    5  311
# 6  12  0.11747  12.5   7.87     0  0.524  6.009  82.9  6.2267    5  311
# 7  13  0.09378  12.5   7.87     0  0.524  5.889  39.0  5.4509    5  311
# 8  14  0.62976   0.0   8.14     0  0.538  5.949  61.8  4.7075    4  307
# 9  15  0.63796   0.0   8.14     0  0.538  6.096  84.5  4.4619    4  307
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# ...

# %% [markdown]
# ## Описание данных таблицы
#
# **crim** -
# уровень преступности на душу населения.
#
# **zn** -
# доля земель под жилую застройку на участках площадью более 25 000 кв. футов.
#
# **indus** -
# доля неторгового бизнеса в акрах на город.
#
# **chas** -
# фиктивная переменная реки Чарльз (= 1, если участок граничит с рекой; 0 в противном случае).
#
# **nox** -
# концентрация оксидов азота (частей на 10 млн).
#
# **rm** -
# среднее количество комнат в жилом доме.
#
# **age** -
# доля жилых единиц, построенных до 1940 года.
#
# **dis** -
# средневзвешенное расстояние до пяти бостонских центров занятости.
#
# **rad** -
# индекс доступности к радиальным магистралям.
#
# **tax** -
# полная ставка налога на имущество за 10 000 долларов США.
#
# **ptratio** -
# соотношение учеников и учителей по городам.
#
# **black** -
# 1000(Bk - 0,63)^2, где Bk — доля чернокожих в городе.
#
# **istat** -
# более низкий статус населения (в процентах).
#
# **medv** -
# средняя стоимость домов, занимаемых владельцами, в 1000 долларов.

# %% [markdown]
# ## График зависимости параметров **dis** от **medv**.
#
# Присвоим x_data значения в колонке **dis**, а y_data - **medv**

# %%
x_data = bh_data['medv']
y_data = bh_data['dis']
plt.plot(x_data, y_data,'o')

# %% [markdown]
# ## Средняя цена
#
# Задание: создать отдельный DataFrame, содержащий только данные для домов, чья цена выше средней цены всех домов в исходных данных.
# Данные о стоимости домов находятся в столбце **medv**.
# Для начала посчитаем среднее значение в этом столбце.

# %%
bh_data['medv'].mean()
# Out:
# 22.768768768768783

# %% [markdown]
# Для удобства округляем полученное значение до десятых:

# %%
round(22.768768768768783, 1)
# Out:
# 22.8

# %% [markdown]
# Теперь имея среднее значение отбираем все данные о домах, чья цена выше средней и вносим их в новый DataFrame -  **rich_boston**:

# %%
rich_boston = bh_data[bh_data['medv'] >= 22.8]
rich_boston.head(10)
# Out:
#     ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 2    4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3    5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4    7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# 11  17  1.05393   0.0   8.14     0  0.538  5.935  29.3  4.4986    4  307
# 21  39  0.17505   0.0   5.96     0  0.499  5.966  30.2  3.8473    5  279
# 22  40  0.02763  75.0   2.95     0  0.428  6.595  21.8  5.4011    3  252
# 23  41  0.03359  75.0   2.95     0  0.428  7.024  15.8  5.4011    3  252
# 24  43  0.14150   0.0   6.91     0  0.448  6.169   6.6  5.7209    3  233
# 25  44  0.15936   0.0   6.91     0  0.448  6.211   6.5  5.7209    3  233
#
#     ptratio   black  lstat  medv
# 0      15.3  396.90   4.98  24.0
# 2      18.7  394.63   2.94  33.4
# 3      18.7  396.90   5.33  36.2
# ...

# %% [markdown]
# Полученный DataFramr заносим в файл **csv**:

# %%
rich_boston.to_csv("rich_boston.csv")
